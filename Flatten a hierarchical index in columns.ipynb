# %% [markdown]
# Link to Stackoverflow
#
# https://stackoverflow.com/questions/14507794/pandas-how-to-flatten-a-hierarchical-index-in-columns
#
# and to the pandas document
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.MultiIndex.to_flat_index.html

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# You can think of MultiIndex as an array of tuples where each tuple is unique.
#
# A MultiIndex can be created from a list of arrays (using MultiIndex.from_arrays()), an array of tuples (using MultiIndex.from_tuples()), a crossed set of iterables (using MultiIndex.from_product()), or a DataFrame (using MultiIndex.from_frame()). The Index constructor will attempt to return a MultiIndex when it is passed a list of tuples.

# %%
dict = {('USAF', ''): {0: '702730', 1: '702731', 2: '702732', 3: '702733',4: '702734'},
        ('WBAN', ''): {0: '26450', 1: '26451', 2: '26452', 3: '26453', 4: '26454'},
        ('day', ''): {0: 1, 1: 2, 2: 3, 3: 4, 4: 5},
        ('month', ''): {0: 1, 1: 1, 2: 1, 3: 1, 4: 1},
        ('s_CD', 'sum'): {0: 12.0, 1: 13.0, 2: 2.0, 3: 12.0, 4: 10.0},
        ('s_CL', 'sum'): {0: 0.0, 1: 0.0, 2: 10.0, 3: 0.0, 4: 0.0},
        ('s_CNT', 'sum'): {0: 13.0, 1: 13.0, 2: 13.0, 3: 13.0, 4: 13.0},
        ('s_PC', 'sum'): {0: 1.0, 1: 0.0, 2: 1.0, 3: 1.0, 4: 3.0},
        ('tempf', 'amax'): {0: 30.9, 1: 32.0, 2: 23.0, 3: 10.0, 4: 19.9},
        ('tempf', 'amin'): {0: 24.98, 1: 24.98, 2: 6.9, 3: 3.9, 4: 10.9}, 
        ('year', ''): {0: 1993, 1: 1993, 2: 1993, 3: 1993, 4: 1993}}

# %%
index = {('USAF', ''): {0: '702730', 1: '702731', 2: '702732', 3: '702733',4: '702734'},
        ('WBAN', ''): {0: '26450', 1: '26451', 2: '26452', 3: '26453', 4: '26454'}
        }

# %%
data =  {('day', ''): {0: 1, 1: 2, 2: 3, 3: 4, 4: 5},
        ('month', ''): {0: 1, 1: 1, 2: 1, 3: 1, 4: 1},
        ('s_CD', 'sum'): {0: 12.0, 1: 13.0, 2: 2.0, 3: 12.0, 4: 10.0},
        ('s_CL', 'sum'): {0: 0.0, 1: 0.0, 2: 10.0, 3: 0.0, 4: 0.0},
        ('s_CNT', 'sum'): {0: 13.0, 1: 13.0, 2: 13.0, 3: 13.0, 4: 13.0},
        ('s_PC', 'sum'): {0: 1.0, 1: 0.0, 2: 1.0, 3: 1.0, 4: 3.0},
        ('tempf', 'amax'): {0: 30.9, 1: 32.0, 2: 23.0, 3: 10.0, 4: 19.9},
        ('tempf', 'amin'): {0: 24.98, 1: 24.98, 2: 6.9, 3: 3.9, 4: 10.9}, 
        ('year', ''): {0: 1993, 1: 1993, 2: 1993, 3: 1993, 4: 1993}}

# %%
index.keys()
# Out:
# dict_keys([('USAF', ''), ('WBAN', '')])

# %%
type(index)
# Out:
# dict

# %%
type(data)
# Out:
# dict

# %% [markdown]
# ## How to create a multi-index by set_index function

# %%
df = pd.DataFrame(dict)
df
# Out:
#      USAF   WBAN day month  s_CD  s_CL s_CNT s_PC tempf         year
#                              sum   sum   sum  sum  amax   amin
# 0  702730  26450   1     1  12.0   0.0  13.0  1.0  30.9  24.98  1993
# 1  702731  26451   2     1  13.0   0.0  13.0  0.0  32.0  24.98  1993
# 2  702732  26452   3     1   2.0  10.0  13.0  1.0  23.0   6.90  1993
# 3  702733  26453   4     1  12.0   0.0  13.0  1.0  10.0   3.90  1993
# 4  702734  26454   5     1  10.0   0.0  13.0  3.0  19.9  10.90  1993

# %%
df[['USAF', 'WBAN']]
# Out:
#      USAF   WBAN
#
# 0  702730  26450
# 1  702731  26451
# 2  702732  26452
# 3  702733  26453
# 4  702734  26454

# %%
df.set_index(['USAF', 'WBAN'])
# Out:
#              day month  s_CD  s_CL s_CNT s_PC tempf         year
#                          sum   sum   sum  sum  amax   amin
# USAF   WBAN
# 702730 26450   1     1  12.0   0.0  13.0  1.0  30.9  24.98  1993
# 702731 26451   2     1  13.0   0.0  13.0  0.0  32.0  24.98  1993
# 702732 26452   3     1   2.0  10.0  13.0  1.0  23.0   6.90  1993
# 702733 26453   4     1  12.0   0.0  13.0  1.0  10.0   3.90  1993
# 702734 26454   5     1  10.0   0.0  13.0  3.0  19.9  10.90  1993

# %% [markdown]
# ## How to create a multi-index as a tuple

# %%
index = pd.DataFrame(index)
index
# Out:
#      USAF   WBAN
#
# 0  702730  26450
# 1  702731  26451
# 2  702732  26452
# 3  702733  26453
# 4  702734  26454

# %%
df2 = pd.DataFrame(data)
# df2.index = pd.MultiIndex.from_tuples(index)
df2.index = index
df2
# Out:
#                 day month  s_CD  s_CL s_CNT s_PC tempf         year
#                             sum   sum   sum  sum  amax   amin
# (702730, 26450)   1     1  12.0   0.0  13.0  1.0  30.9  24.98  1993
# (702731, 26451)   2     1  13.0   0.0  13.0  0.0  32.0  24.98  1993
# (702732, 26452)   3     1   2.0  10.0  13.0  1.0  23.0   6.90  1993
# (702733, 26453)   4     1  12.0   0.0  13.0  1.0  10.0   3.90  1993
# (702734, 26454)   5     1  10.0   0.0  13.0  3.0  19.9  10.90  1993

# %%
df2.index
# Out:
# Index([('702730', '26450'), ('702731', '26451'), ('702732', '26452'),
#        ('702733', '26453'), ('702734', '26454')],
#       dtype='object')

# %%
df2.loc[[('702730', '26450'), ('702731', '26451'), ('702732', '26452'),
       ('702733', '26453'), ('702734', '26454')]]
# Out:
#                 day month  s_CD  s_CL s_CNT s_PC tempf         year
#                             sum   sum   sum  sum  amax   amin
# (702730, 26450)   1     1  12.0   0.0  13.0  1.0  30.9  24.98  1993
# (702731, 26451)   2     1  13.0   0.0  13.0  0.0  32.0  24.98  1993
# (702732, 26452)   3     1   2.0  10.0  13.0  1.0  23.0   6.90  1993
# (702733, 26453)   4     1  12.0   0.0  13.0  1.0  10.0   3.90  1993
# (702734, 26454)   5     1  10.0   0.0  13.0  3.0  19.9  10.90  1993

# %%
df2.index = pd.MultiIndex.from_tuples(df2.index)

# %%
df2
# Out:
#              day month  s_CD  s_CL s_CNT s_PC tempf         year
#                          sum   sum   sum  sum  amax   amin
# 702730 26450   1     1  12.0   0.0  13.0  1.0  30.9  24.98  1993
# 702731 26451   2     1  13.0   0.0  13.0  0.0  32.0  24.98  1993
# 702732 26452   3     1   2.0  10.0  13.0  1.0  23.0   6.90  1993
# 702733 26453   4     1  12.0   0.0  13.0  1.0  10.0   3.90  1993
# 702734 26454   5     1  10.0   0.0  13.0  3.0  19.9  10.90  1993

# %%
index_new = pd.MultiIndex.from_product([['foo', 'bar'], ['baz', 'qux']], names=['a', 'b'])
index_new
# Out:
# MultiIndex([('foo', 'baz'),
#             ('foo', 'qux'),
#             ('bar', 'baz'),
#             ('bar', 'qux')],
#            names=['a', 'b'])

# %%
index_new.to_flat_index()
index_new
# Out:
# MultiIndex([('foo', 'baz'),
#             ('foo', 'qux'),
#             ('bar', 'baz'),
#             ('bar', 'qux')],
#            names=['a', 'b'])
